# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)
print("Libraries loaded")
# Out:
# Libraries loaded

# %%
df_raw   = pd.read_csv('../data/raw/fraudTrain.csv')
df_clean = df_raw.copy()

print(f"Original dataset shape: {df_clean.shape[0]:,} rows × {df_clean.shape[1]} columns")
print(f"Columns: {df_clean.columns.tolist()}")
# Out:
# Original dataset shape: 1,296,675 rows × 23 columns
# Columns: ['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat', 'merch_long', 'is_fraud']

# %% [markdown]
# ### Removing Unnecessary Columns

# %%
if 'Unnamed: 0' in df_clean.columns:
    df_clean = df_clean.drop('Unnamed: 0', axis=1)
    print("Dropped 'Unnamed: 0' (auto-generated index from CSV export)")

print(f"Shape after removal: {df_clean.shape[0]:,} x {df_clean.shape[1]}")
# Out:
# Dropped 'Unnamed: 0' (auto-generated index from CSV export)
# Shape after removal: 1,296,675 x 22

# %% [markdown]
# ### Duplicate Check

# %%
duplicates = df_clean.duplicated().sum()
print(f"Number of duplicate rows: {duplicates:,}")

if duplicates > 0:
    df_clean = df_clean.drop_duplicates()
    print(f"✓ Removed {duplicates:,} duplicate rows")
else:
    print("✓ No duplicates found")

print(f"✓ Shape after duplicate removal: {df_clean.shape[0]:,} rows × {df_clean.shape[1]} columns")

# Check for duplicate transaction numbers
dup_trans = df_clean['trans_num'].duplicated().sum()
print(f"\nDuplicate transaction numbers: {dup_trans:,}")
# Out:
# Number of duplicate rows: 0
# ✓ No duplicates found
# ✓ Shape after duplicate removal: 1,296,675 rows × 22 columns
#
# Duplicate transaction numbers: 0

# %% [markdown]
# ### Missing Values

# %%
missing = df_clean.isnull().sum()
missing = missing[missing > 0]

if len(missing) == 0:
    print("No missing values:")
else:
    print("Missing Values:")
    print(missing)
# Out:
# No missing values:

# %% [markdown]
# ### Data Type Conversions

# %%
# Convert trans_date_trans_time to datetime
df_clean['trans_date_trans_time'] = pd.to_datetime(df_clean['trans_date_trans_time'])
df_clean['dob'] = pd.to_datetime(df_clean['dob'])

# Identifiers - to keep as string
df_clean['cc_num'] = df_clean['cc_num'].astype(str)
df_clean['trans_num'] = df_clean['trans_num'].astype(str)


print("trans_date_trans_time -> datetime")
print("dob                   -> datetime")
print("cc_num, trans_num     -> string")
print(f"\nDate range: {df_clean['trans_date_trans_time'].min()} -> {df_clean['trans_date_trans_time'].max()}")
# Out:
# trans_date_trans_time -> datetime
# dob                   -> datetime
# cc_num, trans_num     -> string
#
# Date range: 2019-01-01 00:00:18 -> 2020-06-21 12:13:37

# %% [markdown]
# ### Feature Engineering - Time

# %%
# Extract time components
df_clean['transaction_hour'] = df_clean['trans_date_trans_time'].dt.hour
df_clean['transaction_day'] = df_clean['trans_date_trans_time'].dt.day_name()
df_clean['transaction_day_of_week'] = df_clean['trans_date_trans_time'].dt.dayofweek
df_clean['transaction_month'] = df_clean['trans_date_trans_time'].dt.month
df_clean['transaction_year'] = df_clean['trans_date_trans_time'].dt.year
df_clean['transaction_date'] = df_clean['trans_date_trans_time'].dt.date

# Behavioral flags
df_clean['is_weekend'] = (df_clean['transaction_day_of_week'] >= 5).astype(int)
df_clean['is_night'] = ((df_clean['transaction_hour'] >= 22) | 
                        (df_clean['transaction_hour'] < 6)).astype(int)

print("transaction_hour, transaction_day, transaction_day_of_week")
print("transaction_month, transaction_year, transaction_date")
print("is_weekend  - 1 if Saturday or Sunday")
print("is_night    - 1 if 10 PM-6 AM")
# Out:
# transaction_hour, transaction_day, transaction_day_of_week
# transaction_month, transaction_year, transaction_date
# is_weekend  - 1 if Saturday or Sunday
# is_night    - 1 if 10 PM-6 AM

# %% [markdown]
# ## Feature Engineering - Amount

# %%
def categorize_amount(amt):
    if   amt <  10:  return 'Very Small'
    elif amt <  50:  return 'Small'
    elif amt < 100:  return 'Medium'
    elif amt < 500:  return 'Large'
    else:            return 'Very Large'

df_clean['amount_category']  = df_clean['amt'].apply(categorize_amount)

# %% [markdown]
# ### Feature Engineering - Card Type (BIN Derivation)
#
# `card_type` does not exist in the raw data. It is derived from the first digits of
# `cc_num` using the **Bank Identification Number (BIN)** standard - the same logic
# used by payment processors to identify card networks:
#
# | Prefix | Network |
# |--------|---------|
# | Starts with `4` | Visa |
# | Starts with `34` or `37` | American Express |
# | Starts with `6011` or `65` | Discover |
# | Starts with `51`-`55` or `2221`-`2720` | Mastercard |
# | Anything else | Other |

# %%
def derive_card_type(cc_num_str):
    n = str(cc_num_str).strip()
    if n.startswith('4'):
        return 'Visa'
    if n[:2] in ('34','37'):
        return 'Amex'
    if n[:4] == '6011' or n[:2] == '65':
        return 'Discover'
    if n[:2] in ('51','52','53','54','55'):
        return 'MasterCard'
    if len(n) >= 4 and n[:4].isdigit() and 2221 <= int(n[:4]) <= 2720:
        return 'MasterCard'
    return 'Other'

df_clean['card_type'] = df_clean['cc_num'].apply(derive_card_type)

print("card_type derived from cc_num BIN prefix\n")
print("Distribution:")
print(df_clean['card_type'].value_counts())
print()
print("Fraud rate by card type:")
ct = df_clean.groupby('card_type').agg(
    Fraud_Count=('is_fraud','sum'),
    Total=('is_fraud','count'),
    Fraud_Rate_Pct=('is_fraud','mean')
)
ct['Fraud_Rate_Pct'] = (ct['Fraud_Rate_Pct']*100).round(4)
print(ct.sort_values('Fraud_Count', ascending=False))
# Out:
# card_type derived from cc_num BIN prefix
#
# Distribution:
# card_type
# Other         552015
# Visa          418825
# Amex          123834
# Discover      105436
# MasterCard     96565
# Name: count, dtype: int64
#
# Fraud rate by card type:
#             Fraud_Count   Total  Fraud_Rate_Pct
# card_type
# Other              3167  552015            0.57
# Visa               2441  418825            0.58
# Discover            650  105436            0.62
# Amex                626  123834            0.51
# MasterCard          622   96565            0.64

# %%
df_clean.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category    amt      first     last gender  \
# 0       misc_net   4.97   Jennifer    Banks      F
# 1    grocery_pos 107.23  Stephanie     Gill      F
# 2  entertainment 220.11     Edward  Sanchez      M
# 3  gas_transport  45.00     Jeremy    White      M
# 4       misc_pos  41.96      Tyler   Garcia      M
#
#                          street            city state    zip   lat    long  \
# 0                561 Perry Cove  Moravian Falls    NC  28654 36.08  -81.18
# ...

# %%
df_clean.to_csv("../data/cleaned/fraudtrain_clean.csv", index=False)
